# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv("spotify.csv", encoding='latin1')
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.columns.tolist()
# Out:
# ['track_name',
#  'artist(s)_name',
#  'artist_count',
#  'released_year',
#  'released_month',
#  'released_day',
#  'in_spotify_playlists',
#  'in_spotify_charts',
#  'streams',
#  'in_apple_playlists',
#  'in_apple_charts',
#  'in_deezer_playlists',
#  'in_deezer_charts',
#  'in_shazam_charts',
#  'bpm',
#  'key',
#  'mode',
#  'danceability_%',
#  'valence_%',
#  'energy_%',
#  'acousticness_%',
#  'instrumentalness_%',
#  'liveness_%',
#  'speechiness_%']

# %%
df.sort_values(by='artist_count', ascending=False).head(25)
# Out:
#                                             track_name  \
# 642                                           Se Le Ve
# 35                                     Los del Espacio
# 667  Cayï¿½ï¿½ La Noche (feat. Cruz Cafunï¿½ï¿½, Ab...
# 506                          We Don't Talk About Bruno
# 393                                  Jhoome Jo Pathaan
# 759                 Nobody Like U - From "Turning Red"
# 402                     Besharam Rang (From "Pathaan")
# 864                                   ULTRA SOLO REMIX
# 328                                   Marisola - Remix
# 201  Angel Pt 1 (feat. Jimin of BTS, JVKE & Muni Long)
# 137        Tere Vaaste (From "Zara Hatke Zara Bachke")
# 238  Link Up (Metro Boomin & Don Toliver, Wizkid fe...
# 488                                    Tubarï¿½ï¿½o Te
# 200  Annihilate (Spider-Man: Across the Spider-Vers...
# 197                                    POLARIS - Remix
# 141                                      Novo Balanï¿½
# ...

# %%
df.sort_values(by='artist_count',ascending=False).drop_duplicates(subset='track_name')
# Out:
#                                             track_name  \
# 642                                           Se Le Ve
# 35                                     Los del Espacio
# 667  Cayï¿½ï¿½ La Noche (feat. Cruz Cafunï¿½ï¿½, Ab...
# 506                          We Don't Talk About Bruno
# 393                                  Jhoome Jo Pathaan
# ..                                                 ...
# 186                                       Pink + White
# 526                                             Beggin
# 185                                            Cheques
# 184                                         Apocalypse
# 952                                              Alone
#
#                                         artist(s)_name  artist_count  \
# 642  Arcangel, De La Ghetto, Justin Quiles, Lenny T...             8
# 35   Big One, Duki, Lit Killah, Maria Becerra, FMK,...             8
# 667  Quevedo, La Pantera, Juseph, Cruz Cafunï¿½ï¿½,...             7
# ...

# %%
df.sort_values(by='artist_count', ascending=False).head(25).drop_duplicates(subset='artist(s)_name')
# Out:
#                                      track_name       artist(s)_name  \
# 952                                       Alone            Burna Boy
# 419                                      Gatita            Bellakath
# 761                                  Photograph           Ed Sheeran
# 760                                  Still Life              BIGBANG
# 422                                    Yonaguni            Bad Bunny
# 423                           Super Freaky Girl          Nicki Minaj
# 424      Running Up That Hill (A Deal With God)            Kate Bush
# 425                                    Dream On            Aerosmith
# 426                                       Limbo        Freddie Dredd
# 758                                  Ain't Shit             Doja Cat
# 756                                      Golden         Harry Styles
# 430                                   KICK BACK        Kenshi Yonezu
# 431  Evergreen (You Didnï¿½ï¿½ï¿½t Deserve Me A          Omar Apollo
# ...

# %%
top_10_track = df.sort_values(by='artist_count', ascending=False).head(25).drop_duplicates(subset='track_name')[['track_name', 'artist_count']]
px.bar(top_10_track, 'artist_count', 'track_name', title='Top 10 Tracks')

# %%
released_year = df.groupby('released_year')
for year in df.released_year.unique().tolist():
    sdf = released_year.get_group(year)
    player_df = sdf.sort_values(by='artist_count', ascending=False).head()[['artist(s)_name', 'artist_count']]
    fig = px.bar(player_df, 'artist(s)_name','artist_count', title=f'Top 5 Track in {released_year}',width=500)
    fig.show()
